# %% [markdown]
# # Visualizing 2D data with `matplotlib`
#
# Dataset for this module: https://berkeley-earth-temperature.s3.us-west-1.amazonaws.com/Global/Gridded/Land_and_Ocean_EqualArea.nc
#
# Reference on plotting: https://earth-env-data-science.github.io/lectures/basic_scipy/more_matplotlib.html#d-plotting-methods
# Reference on reading in netcdf files with xarray: https://earth-env-data-science.github.io/lectures/xarray/xarray.html#loading-data-from-netcdf-files
#
# Please use this notebook to develop a 1.5 hr module to:
# - load in the gridded dataset of earth's surface temperature
# - select one time point for plotting (`.isel(time=n)`)
# - plot the surface temperature of the earth using pcolormesh
# - customize the plots by adjusting colorscale, colormaps, axis limits

# %%
import xarray as xr
data_file = '../data/Land_and_Ocean_EqualArea.nc'
ds = xr.open_dataset(data_file)

# %%
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:      (map_points: 15984, time: 2093, month_number: 12)
# Coordinates:
#     longitude    (map_points) float32 ...
#     latitude     (map_points) float32 ...
#   * time         (time) float64 1.85e+03 1.85e+03 ... 2.024e+03 2.024e+03
# Dimensions without coordinates: map_points, month_number
# Data variables:
#     land_mask    (map_points) float64 ...
#     temperature  (time, map_points) float32 ...
#     climatology  (month_number, map_points) float32 ...
# Attributes:
#     Conventions:           Berkeley Earth Internal Convention (based on CF-1.5)
#     title:                 Native Format Berkeley Earth Surface Temperature A...
#     history:               11-Jul-2024 01:58:02
#     institution:           Berkeley Earth Surface Temperature Project
#     land_source_history:   08-Jul-2024 10:18:28
#     ocean_source_history:  16-Jun-2024 08:23:06
#     comment:               This file contains Berkeley Earth surface temperat...

# %%
ds.temperature.isel(time=-1).plot()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (map_points: 15984, time: 2093, month_number: 12)
# Coordinates:
#     longitude    (map_points) float32 ...
#     latitude     (map_points) float32 ...
#   * time         (time) float64 1.85e+03 1.85e+03 ... 2.024e+03 2.024e+03
# Dimensions without coordinates: map_points, month_number
# Data variables:
#     land_mask    (map_points) float64 ...
#     temperature  (time, map_points) float32 ...
#     climatology  (month_number, map_points) float32 ...
# Attributes:
#     Conventions:           Berkeley Earth Internal Convention (based on CF-1.5)
#     title:                 Native Format Berkeley Earth Surface Temperature A...
#     history:               11-Jul-2024 01:58:02
#     institution:           Berkeley Earth Surface Temperature Project
#     land_source_history:   08-Jul-2024 10:18:28
#     ocean_source_history:  16-Jun-2024 08:23:06
#     comment:               This file contains Berkeley Earth surface temperat...

# %%
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:      (map_points: 15984, time: 2093, month_number: 12)
# Coordinates:
#     longitude    (map_points) float32 ...
#     latitude     (map_points) float32 ...
#   * time         (time) float64 1.85e+03 1.85e+03 ... 2.024e+03 2.024e+03
# Dimensions without coordinates: map_points, month_number
# Data variables:
#     land_mask    (map_points) float64 ...
#     temperature  (time, map_points) float32 ...
#     climatology  (month_number, map_points) float32 ...
# Attributes:
#     Conventions:           Berkeley Earth Internal Convention (based on CF-1.5)
#     title:                 Native Format Berkeley Earth Surface Temperature A...
#     history:               11-Jul-2024 01:58:02
#     institution:           Berkeley Earth Surface Temperature Project
#     land_source_history:   08-Jul-2024 10:18:28
#     ocean_source_history:  16-Jun-2024 08:23:06
#     comment:               This file contains Berkeley Earth surface temperat...

# %%
print(ds.temperature)
# Out:
# <xarray.DataArray 'temperature' (time: 2093, map_points: 15984)>
# [33454512 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#   * time       (time) float64 1.85e+03 1.85e+03 1.85e+03 ... 2.024e+03 2.024e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degree C
#     standard_name:  surface_temperature_anomaly
#     long_name:      Air Surface Temperature Anomaly
#     valid_min:      -17.37408174372588
#     valid_max:      22.94248731931051

# %%
print(ds.temp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(ds.temp)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\xarray\core\common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'temp'

# %%
ds.temperature.isel(time=-1)
# Out:
# <xarray.DataArray 'temperature' (map_points: 15984)>
# [15984 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#     time       float64 2.024e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degree C
#     standard_name:  surface_temperature_anomaly
#     long_name:      Air Surface Temperature Anomaly
#     valid_min:      -17.37408174372588
#     valid_max:      22.94248731931051

# %%
ds.temperature
# Out:
# <xarray.DataArray 'temperature' (time: 2093, map_points: 15984)>
# [33454512 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#   * time       (time) float64 1.85e+03 1.85e+03 1.85e+03 ... 2.024e+03 2.024e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degree C
#     standard_name:  surface_temperature_anomaly
#     long_name:      Air Surface Temperature Anomaly
#     valid_min:      -17.37408174372588
#     valid_max:      22.94248731931051

# %%
ds.temperature.isel(time=-1)
# Out:
# <xarray.DataArray 'temperature' (map_points: 15984)>
# [15984 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#     time       float64 2.024e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degree C
#     standard_name:  surface_temperature_anomaly
#     long_name:      Air Surface Temperature Anomaly
#     valid_min:      -17.37408174372588
#     valid_max:      22.94248731931051

# %%
ds.temperature.longitude
# Out:
# <xarray.DataArray 'longitude' (map_points: 15984)>
# [15984 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degrees_east
#     standard_name:  longitude
#     long_name:      Longitude

# %%
import matplotlib as plt

# %%
ds.temperature
# Out:
# <xarray.DataArray 'temperature' (time: 2093, map_points: 15984)>
# [33454512 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#   * time       (time) float64 1.85e+03 1.85e+03 1.85e+03 ... 2.024e+03 2.024e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degree C
#     standard_name:  surface_temperature_anomaly
#     long_name:      Air Surface Temperature Anomaly
#     valid_min:      -17.37408174372588
#     valid_max:      22.94248731931051

# %%
ds.temperature.isel(time=100)
# Out:
# <xarray.DataArray 'temperature' (map_points: 15984)>
# [15984 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#     time       float64 1.858e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degree C
#     standard_name:  surface_temperature_anomaly
#     long_name:      Air Surface Temperature Anomaly
#     valid_min:      -17.37408174372588
#     valid_max:      22.94248731931051

# %%
ds.temperature.isel(time=10)
# Out:
# <xarray.DataArray 'temperature' (map_points: 15984)>
# [15984 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#     time       float64 1.851e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degree C
#     standard_name:  surface_temperature_anomaly
#     long_name:      Air Surface Temperature Anomaly
#     valid_min:      -17.37408174372588
#     valid_max:      22.94248731931051

# %%
print(ds.temperature.isel(time=10))
# Out:
# <xarray.DataArray 'temperature' (map_points: 15984)>
# [15984 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#     time       float64 1.851e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degree C
#     standard_name:  surface_temperature_anomaly
#     long_name:      Air Surface Temperature Anomaly
#     valid_min:      -17.37408174372588
#     valid_max:      22.94248731931051

# %%
from IPython.display import display, HTML

# %%
print(ds.temperature.isel(time=10))
# Out:
# <xarray.DataArray 'temperature' (map_points: 15984)>
# [15984 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#     time       float64 1.851e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degree C
#     standard_name:  surface_temperature_anomaly
#     long_name:      Air Surface Temperature Anomaly
#     valid_min:      -17.37408174372588
#     valid_max:      22.94248731931051

# %%
print(ds.temperature.isel(time=10).longitude)
# Out:
# <xarray.DataArray 'longitude' (map_points: 15984)>
# [15984 values with dtype=float32]
# Coordinates:
#     longitude  (map_points) float32 ...
#     latitude   (map_points) float32 ...
#     time       float64 1.851e+03
# Dimensions without coordinates: map_points
# Attributes:
#     units:          degrees_east
#     standard_name:  longitude
#     long_name:      Longitude

# %%
print(ds.temperature.isel(time=10, longitude=))
